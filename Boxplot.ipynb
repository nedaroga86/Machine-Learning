# %% [markdown]
# ## Example 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.array ([-20,-3,-2,-1,0,1,2,3,4,5,8,9,10,11,12,13,15,16,19,40,50])
data
# Out:
# array([-20,  -3,  -2,  -1,   0,   1,   2,   3,   4,   5,   8,   9,  10,
#         11,  12,  13,  15,  16,  19,  40,  50])

# %%
q1 = np.quantile(data, 0.25)
q2 = np.quantile(data, 0.50)
q3 = np.quantile(data, 0.75)

# %%
print(f'Q1: {q1}')
print(f'Q2: {q2}')
print(f'Q3: {q3}')
# Out:
# Q1: 1.0
# Q2: 8.0
# Q3: 13.0

# %%
IQR = q3-q1
print(f'IQR: {IQR}')
# Out:
# IQR: 12.0

# %%
lower = q1 - 1.5 * IQR
upper = q3 + 1.5 * IQR
print(f'Lower bound: {lower}')
print(f'Upper bound: {upper}')
# Out:
# Lower bound: -17.0
# Upper bound: 31.0

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2436db132f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2436db137d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2436db13110>],
#  'medians': [<matplotlib.lines.Line2D at 0x2436db13e00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2436db44140>],
#  'means': []}

# %% [markdown]
# ## Example 2

# %%
class_1 = np.array([60,70,80,85,87,88,89,90,92,94,95,97,100,101])
class_2 = np.array([130,143,150,158,160,170,175,182,185,188,190,200,280,300])

# %%
plt.boxplot([class_1,class_2], patch_artist = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2436fe35a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2436fe35fa0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2436dc79f10>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2436fe36540>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2436fe36870>,
# ...
#  'means': []}
